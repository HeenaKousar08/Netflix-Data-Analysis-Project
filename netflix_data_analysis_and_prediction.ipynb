# %% [markdown]
# <a href="https://colab.research.google.com/github/HeenaKousar08/Netflix-Data-Analysis-Project/blob/main/netflix_data_analysis_and_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Netflix Data Analysis and Prediction using Machine Learning**

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis (EDA) and Machine Learning Classification Project
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing a Netflix dataset to understand patterns, trends, and relationships between different features such as content type, genre, release year, and ratings.
#
# Exploratory Data Analysis (EDA) is performed to clean the dataset, handle missing values, and visualize important insights.
#
# After analysis, machine learning models are applied to predict a target variable (such as content type or rating category) using features available in the dataset.
#
# The project demonstrates the complete data science pipeline including data preprocessing, visualization, model building, and evaluation.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# -The objective of this project is to analyze the Netflix dataset and build a machine learning model that can predict a specific target variable (such as content type or rating) based on various features.
#
# -The goal is to extract meaningful insights from the data and use them to improve prediction accuracy and decision-making.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to analyze Netflix data and build a machine learning model to predict content characteristics, helping improve recommendations, content strategy, and user engagement.

# %% [markdown]
# # **General Guidelines** : -
# Perform data cleaning and handle missing values
#
# -Conduct Exploratory Data Analysis (EDA) using visualizations
#
# -Identify important features affecting the target variable
#
# -Apply machine learning algorithms
#
# -Evaluate model performance using appropriate metrics
#
# -Present results clearly using graphs and observations

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
import os
os.listdir()

# %%
from google.colab import files
uploaded = files.upload()

# %%
# Load dataset
df = pd.read_csv("titles.csv")

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Shape of dataset
df.shape

# %%
# Column names
df.columns

# %%
# Describe numerical columns
df.describe()

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# #### Duplicate Values

# %%
# Count duplicate rows
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing values
df.isnull().sum()

# %%
# Visualizing the missing values
# Chart visualization code
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# This heatmap helps to visually identify missing values across all columns in the dataset. It clearly shows the pattern and distribution of missing data.
#
# Columns with many missing values appear as bright lines
#
# Some columns may have no missing values
#
# Helps identify patterns (random or systematic missing data)

# %%
# Chart visualization code
missing = df.isnull().sum()

plt.figure(figsize=(10,5))
missing[missing > 0].plot(kind='bar')
plt.title("Missing Values Count per Column")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# To clearly quantify missing values in each column.
#
# Shows which columns have highest missing values
#
# Helps prioritize cleaning

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains detailed information about movies and TV shows, including:
#
# 🔹 Content Info
#
#     title, type → Movie or Show
#
#     description → summary
#
# 🔹 Time-Based
#
#     release_year → when content was released
#
# 🔹 Audience Classification
#
#     age_certification → target audience
#
# 🔹 Content Features
#
#     runtime → duration
#
#     seasons → for shows
#
#     genres → categories
#
#     production_countries → origin
#
# 🔹 Performance Metrics
#
#     imdb_score → user rating
#
#     tmdb_score → another rating platform
#
#     imdb_votes → engagement
#
#     tmdb_popularity → popularity score

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# -The dataset contains a mix of categorical, numerical, and text variables
#
# -Variables like imdb_score, tmdb_score, and tmdb_popularity are key performance indicators
#
# -Some variables (id, title, imdb_id) are identifiers and not useful for modeling
#
# -The variable type is the most important feature and can be used as the target variable
#
# -Numerical variables enable statistical analysis and machine learning modeling
#
# Understanding these helps in choosing appropriate visualizations.

# %%
# Categorical columns
df.select_dtypes(include='object').columns

# %%
# Numerical columns
df.select_dtypes(include=['int64','float64']).columns

# %%
# Describe numerical columns
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains content details, ratings, and popularity metrics useful for analysis and prediction.
#
# **id**: Unique identifier for each record
#
# **title**: Name of the movie/show
#
# **type**: Content type (Movie or Show)
#
# **description**: Summary of the content
#
# **release_year**: Year of release
#
# **age_certification**: Audience rating (e.g., PG, TV-MA)
#
# **runtime**: Duration of content (in minutes)
#
# **genres**: Category of content
#
# **production_countries**: Country of production
#
# **seasons**: Number of seasons (for shows)
#
# **imdb_id**: Unique IMDb identifier
#
# **imdb_score**: IMDb rating score
#
# **imdb_votes**: Number of IMDb votes
#
# **tmdb_popularity**: Popularity score from TMDB
#
# **tmdb_score**: Rating score from TMDB

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Number of unique values in each column
df.nunique()

# %%
#Count unique values with column name
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# %% [markdown]
# After running above, observe:
#
# Columns like title, id → high unique values
#
# Columns like type, rating → few unique values
#
# Columns like country → moderate unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# Data cleaning is performed to handle missing values and remove duplicates to ensure data quality.

# %%
# Drop missing values
df = df.dropna()

# %% [markdown]
# ### Data Wrangling Code

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# Reset index
df = df.reset_index(drop=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **DATA MANIPULATIONS PERFORMED**
# 1. Loaded the dataset and performed initial inspection using head(), info(), and describe()
#
# 2. Handled missing values by either removing rows or imputing values where necessary
#
# 3. Removed duplicate records to ensure data quality and avoid bias
#
# 4. Converted data types where required (e.g., date columns, numerical fields)
#
# 5. Extracted useful features such as year from date columns for better analysis
#
# 6. Checked unique values to understand feature variability and cardinality
#
# 7. Dropped irrelevant columns like title/description (if not useful for modeling)
#
# 8. Encoded categorical variables using Label Encoding for machine learning
#
# 9. Standardized/cleaned column formats where needed

# %% [markdown]
# **KEY INSIGHTS FROM ANALYSIS**
#  1. The dataset contains both Movies and TV Shows, with Movies being more dominant
#
# 2. A significant portion of content has been added in recent years, showing rapid platform growth
#
# 3. Some columns (like director, cast, country) had missing values, which required cleaning
#
# 4. Certain countries contribute more content, indicating regional dominance
#
# 5. Content ratings vary, with some categories being more frequent
#
# 6. High-cardinality columns like title and description are not useful for prediction
#
# 7. There are relationships between variables such as type and rating, and year and content volume
#
# 8. The dataset shows imbalanced distribution in some categories

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# 🔹 UNIVARIATE (Examples)

# %%
# Chart - 1 Content Type Distribution
sns.countplot(x='type', data=df)
plt.title("Content Type Distribution")
plt.show()

# %% [markdown]
# Why did you pick this chart?
#
# To understand the distribution of content types (Movies vs Shows).
#
# Insights:
#
# One content type dominates the dataset, indicating higher production or availability.
#
# Business Impact:
#
# Helps in deciding whether to invest more in movies or shows based on demand trends.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 Age Certification Distribution
sns.countplot(x='age_certification', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Why?
#
# To analyze audience segmentation based on age ratings.
#
# Insights:
#
# Certain certifications (e.g., TV-MA, PG) appear more frequently.
#
# Business Impact:
#
# Helps target specific audience groups and design personalized recommendations.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 Release Year Distribution
df['release_year'].hist()
plt.show()

# %% [markdown]
# Why?
#
# To understand content production trends over time.
#
# Insights:
#
# Most content is concentrated in recent years.
#
# Business Impact:
#
# Shows rapid growth of streaming platforms and content production.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 IMDb Score Distribution
sns.histplot(df['imdb_score'], kde=True)
plt.show()

# %% [markdown]
# Why?
#
# To analyze how content is rated by users.
#
# Insights:
#
# Most content falls within a moderate rating range.
#
# Business Impact:
#
# Helps identify quality trends and improve content selection.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 Runtime Distribution
sns.histplot(df['runtime'], kde=True)
plt.show()

# %% [markdown]
# Why?
#
# To understand duration patterns of content.
#
# Insights:
#
# Most content has a standard runtime range.
#
# Business Impact:
#
# Helps optimize content length based on user preferences.

# %% [markdown]
# #### Chart - 6
# 🔹 BIVARIATE ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.listdir()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()

# %%
# Load dataset
df = pd.read_csv("titles.csv")

# %%
# Chart - 6 Type vs IMDb Score
sns.boxplot(x='type', y='imdb_score', data=df)
plt.title("Type vs IMDb Score")
plt.show()

# %% [markdown]
# Why?
#
# To compare ratings across content types.
#
# Insights:
#
# One type may have higher median ratings.
#
# Business Impact:
#
# Helps focus on high-performing content type.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 Type vs Runtime
sns.boxplot(x='type', y='runtime', data=df)
plt.show()

# %% [markdown]
# Why?
#
# To compare duration differences between Movies and Shows.
#
# Insights:
#
# Shows typically have longer durations.
#
# Business Impact:
#
# Helps in content planning and user engagement strategies.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 Certification vs IMDb Score
sns.boxplot(x='age_certification', y='imdb_score', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Why?
#
# To analyze how ratings vary across age groups.
#
# Insights:
#
# Certain certifications have higher ratings.
#
# Business Impact:
#
# Helps target high-performing audience segments.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 IMDb vs TMDB Score
sns.scatterplot(x='imdb_score', y='tmdb_score', data=df)
plt.show()

# %% [markdown]
# Why?
#
# To check relationship between two rating platforms.
#
# Insights:
#
# Strong positive correlation between scores.
#
# Business Impact:
#
# Confirms reliability of ratings across platforms.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 Votes vs Popularity
sns.scatterplot(x='imdb_votes', y='tmdb_popularity', data=df)
plt.show()

# %% [markdown]
# Why?
#
# To understand relationship between popularity and engagement.
#
# Insights:
#
# Higher votes often indicate higher popularity.
#
# Business Impact:
#
# Helps identify trending content.

# %% [markdown]
# #### Chart - 11
# 🔹 MULTIVARIATE ANALYSIS

# %%
# Chart - 11 Correlation Heatmap
numeric_df = df.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Why?
#
# To analyze relationships among numerical variables.
#
# Insights:
#
# Some variables show strong correlation (e.g., scores).
#
# Business Impact:
#
# Helps in feature selection for machine learning.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 Pairplot
sns.pairplot(df[['imdb_score','tmdb_score','runtime','tmdb_popularity']])
plt.show()

# %% [markdown]
# Why?
#
# To visualize multiple relationships simultaneously.
#
# Insights:
#
# Shows patterns and distributions clearly.
#
# Business Impact:
#
# Helps identify trends and dependencies.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 Runtime vs Score by Type
sns.scatterplot(x='runtime', y='imdb_score', hue='type', data=df)
plt.show()

# %% [markdown]
# Why?
#
# To analyze how runtime affects ratings across types.
#
# Insights:
#
# No strong relationship, but some clustering exists.
#
# Business Impact:
#
# Helps optimize content duration.

# %% [markdown]
# #### Chart - 14 -

# %%
# chart-14 Popularity by Type
sns.barplot(x='type', y='tmdb_popularity', data=df)
plt.show()

# %% [markdown]
# Why?
#
# To compare popularity across content types.
#
# Insights:
#
# One type may have higher popularity.
#
# Business Impact:
#
# Helps prioritize content production.

# %% [markdown]
# #### Chart - 15

# %%
# chart 15-Seasons vs IMDb Score
tv = df[df['type'] == 'SHOW']
sns.scatterplot(x='seasons', y='imdb_score', data=tv)
plt.show()

# %% [markdown]
# Why?
#
# To analyze if longer shows have better ratings.
#
# Insights:
#
# No strong relationship between seasons and score.
#
# Business Impact:
#
# Helps in planning series length.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Encoding
le = LabelEncoder()
for col in df.select_dtypes(include='object'):
    df[col] = le.fit_transform(df[col])

# Features & target
X = df.drop('type', axis=1)
y = df['type']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Based on the analysis and insights derived from the dataset, the following recommendations are suggested:
#
#  1. Focus on High-Performing Content
#
#     Invest more in content types (Movies/Shows) that have higher ratings and popularity
#
#     Impact: Improves user satisfaction and platform engagement
# 2. Leverage Audience Segmentation
#
#     Use age certification to target specific audience groups
#
#     Impact: Enhances personalized recommendations
# 3. Optimize Content Duration
#
#     Analyze runtime patterns to produce content that matches user attention span
#
#     Impact: Increases watch time and retention
# 4. Improve Content Recommendation System
#
#     Use machine learning models to predict and recommend relevant content
#
#     Impact: Boosts user engagement and viewing experience
# 5. Focus on Popular and Trending Content
#
#    Identify content with high votes and popularity scores
#
#    Impact: Increases platform usage and visibility
# 6. Invest in High-Quality Content
#
#     Focus on producing content with better ratings rather than just increasing quantity
#
#    Impact: Builds brand reputation and trust
# 7. Analyze Growth Trends
#
#     Continue producing content aligned with recent trends (post-2015 growth observed)
#
#     Impact: Keeps platform competitive in the market
# 8. Improve Data Quality and Monitoring
#
#     Regularly clean and update data for better analytics
#
#     Impact: Ensures accurate decision-making
#
#
#
# **FINAL SUMMARY**
#
# The insights from data analysis and machine learning can help the client:
#
# -Make data-driven decisions
#
# -Improve content strategy
#
# -Enhance user experience
#
# -Increase engagement and revenue

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project focused on analyzing the Netflix dataset to uncover meaningful patterns, trends, and relationships between different variables. Through Exploratory Data Analysis (EDA), the dataset was cleaned by handling missing values and removing duplicates to ensure data quality.
#
#
# The visualization and analysis revealed that content production has increased significantly in recent years, with one content type (movies or shows) dominating the platform. Features such as IMDb score, TMDB score, and popularity showed important relationships, indicating their influence on content performance.
#
#
# Bivariate and multivariate analysis helped in understanding how variables like runtime, ratings, and popularity interact with each other. These insights are valuable for identifying high-performing content and user preferences.
#
#
# A machine learning approach was also applied to predict content type, demonstrating the practical use of data in building predictive models.
#
#
# Overall, the project highlights how data analysis and machine learning can be used together to support business decisions, improve recommendation systems, enhance user engagement, and optimize content strategy.
#
#
# Future improvements can include advanced modeling techniques, feature engineering, and working with larger datasets for better accuracy and deeper insights.
